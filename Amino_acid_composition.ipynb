# %%
import re, os,sys
from collections import Counter

# Will define two functions....
#1. Reading Fasta File
#2. Generating Amino Acid composition of Protein Fasta File.

def ReadFasta(FileName):
    if not os.path.exists(FileName):
        print('Error: "' + FileName + '" does not exist.')
        sys.exit(1)
    with open(FileName) as f:
        records = f.read()
    if re.search('>', records) is None:
        print('The input file seems not in fasta format.')
        sys.exit(1)
    records = records.split('>')[1:]
    myFasta = []
    for fasta in records:
        array = fasta.split('\n')
        name, sequence= array[0].split()[0], re.sub('^ARNDCQEGHILKMFPSTWYV-', '-', ''.join(array[1:]).upper())
        myFasta.append([name, sequence])
        
    return myFasta

def AAC(FastaFile):
    AA= 'ACDEFGHIKLMNPQRSTVWY'
    encodings=[]
    header=['Protein']
    # result=['Result']
    for i in AA:
        header.append(i)         
    encodings.append(header) 
    fastas=ReadFasta(FastaFile)

    for i in fastas:
        name, sequence=i[0], re.sub('-','',i[1])
        count=Counter(sequence)
        for key in count:
            count[key]=count[key]/len(sequence)
        code=[name]
        for aa in AA:            
            code.append(count[aa])
        encodings.append(code)

    return encodings


# create a main function to generate AAC
if __name__=='__main__':
    FastaFile='UniSwiss-Tst-nega.fasta'
    Encodings=AAC(FastaFile)
    # Create a file / open a file to save the feature vector of the AAC
    with open ('uniswiss-tr-nega.csv', 'w') as Fin:
        for each in Encodings:
            Fin.write(str(each))
            Fin.write('\n')
# Out:
# Error: "UniSwiss-Tst-nega.fasta" does not exist.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import re, os,sys
from collections import Counter

# Will define two functions....
#1. Reading Fasta File
#2. Generating Amino Acid composition of Protein Fasta File.

def ReadFasta(FileName):
    if not os.path.exists(FileName):
        print('Error: "' + FileName + '" does not exist.')
        sys.exit(1)
    with open(FileName) as f:
        records = f.read()
    if re.search('>', records) is None:
        print('The input file seems not in fasta format.')
        sys.exit(1)
    records = records.split('>')[1:]
    myFasta = []
    for fasta in records:
        array = fasta.split('\n')
        name, sequence = array[0].split()[0], re.sub('[^ARNDCQEGHILKMFPSTWYV-]', '-', ''.join(array[1:]).upper())
        myFasta.append([name, sequence])
    return myFasta

def AAC(FastaFile):
    AA= 'ACDEFGHIKLMNPQRSTVWY'
    encodings=[]
    header=['Protein']
    for i in AA:
        header.append(i)
    encodings.append(header)
    fastas=ReadFasta(FastaFile)
    for i in fastas:
        name, sequence=i[0], re.sub('-','',i[1])
        count=Counter(sequence)
        # print(count)
        for key in count:
            count[key]=count[key]/len(sequence)
            # print(count[key])
        code=[name]
        for aa in AA:
            code.append(count[aa])
        encodings.append(code)
    return encodings


# create a main function to generate AAC
if __name__=='__main__':
    FastaFile='UniSwiss-Tst-posi.fasta'
    Encodings=AAC(FastaFile)
    # Create a file / open a file to save the feature vector of the AAC
    with open ('uniswiss-tr-posi.csv', 'w') as Fin:
        for each in Encodings:
            Fin.write(str(each))
            Fin.write('\n')
# Out:
# Error: "UniSwiss-Tst-posi.fasta" does not exist.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data_neg = pd.read_csv('uniswiss-tr-nega.csv')
display(data_neg)
# Out:
#      ['Protein'       'A'       'C'  ...       'V'       'W'                    'Y']
# 0     ['P50491'  0.054662  0.027331  ...  0.046624  0.009646    0.06270096463022508]
# 1     ['O06928'  0.084699  0.010929  ...  0.081967  0.010929    0.01912568306010929]
# 2     ['Q8STG1'  0.032520  0.040650  ...  0.056911  0.040650   0.008130081300813009]
# 3     ['A3KN12'  0.093878  0.028571  ...  0.057143  0.010204   0.018367346938775512]
# 4     ['B7F8P5'  0.064327  0.029240  ...  0.070175  0.005848   0.029239766081871343]
# ...         ...       ...       ...  ...       ...       ...                     ...
# 4495  ['P0C2S7'  0.096774  0.139785  ...  0.075269  0.021505   0.021505376344086023]
# 4496  ['Q8SV35'  0.049180  0.026230  ...  0.068852  0.003279   0.003278688524590164]
# 4497  ['O74509'  0.049853  0.008798  ...  0.058651  0.011730    0.02346041055718475]
# 4498  ['P22642'  0.073333  0.020000  ...  0.040000  0.006667   0.013333333333333334]
# 4499  ['O74508'  0.040094  0.035377  ...  0.058962  0.011792   0.018867924528301886]
#
# [4500 rows x 21 columns]

# %%
data_neg['Result'] = 0
data_neg.head()
# Out:
#   ['Protein'       'A'       'C'  ...       'W'                    'Y']  Result
# 0  ['P50491'  0.054662  0.027331  ...  0.009646    0.06270096463022508]       0
# 1  ['O06928'  0.084699  0.010929  ...  0.010929    0.01912568306010929]       0
# 2  ['Q8STG1'  0.032520  0.040650  ...  0.040650   0.008130081300813009]       0
# 3  ['A3KN12'  0.093878  0.028571  ...  0.010204   0.018367346938775512]       0
# 4  ['B7F8P5'  0.064327  0.029240  ...  0.005848   0.029239766081871343]       0
#
# [5 rows x 22 columns]

# %%
X = data_neg['Protein','A','C','D','E','F','G','H','I','K','L','M','N','P','Q','R','S','T','V','W','Y']
Y = data_neg['Result']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Protein', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d12d105488c4> in <module>()
# ----> 1 X = data_neg['Protein','A','C','D','E','F','G','H','I','K','L','M','N','P','Q','R','S','T','V','W','Y']
#       2 Y = data_neg['Result']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: ('Protein', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y')

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
X = StandardScaler().fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-152947327e5b> in <module>()
#       1
#       2 label_encoder = LabelEncoder()
# ----> 3 Y = label_encoder.fit_transform(Y)
#       4 X = StandardScaler().fit_transform(X)
#
# NameError: name 'Y' is not defined

# %%
X_train , X_test, y_train, y_test = train_test_split(X,Y)
clf = SVC(C=1.0, kernel='rbf').fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-93f22bda1f37> in <module>()
# ----> 1 X_train , X_test, y_train, y_test = train_test_split(X,Y)
#       2 clf = SVC(C=1.0, kernel='rbf').fit(X_train,y_train)
#
# NameError: name 'train_test_split' is not defined
